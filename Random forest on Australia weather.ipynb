# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('weatherAUS.csv')

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.tail(10)
# Out:
#              Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 76103  2012-02-28  Portland      9.7     21.1       0.0          4.0
# 76104  2012-02-29  Portland     15.2     19.3       0.0          4.0
# 76105  2012-03-01  Portland     15.7     19.9       6.4          1.4
# 76106  2012-03-02  Portland     14.5     21.4       0.6          3.6
# 76107  2012-03-03  Portland     13.4     17.3       1.0          6.2
# 76108  2012-03-04  Portland     14.4     20.8      16.6          1.2
# 76109  2012-03-05  Portland     13.2     18.8       2.6          5.8
# 76110  2012-03-06  Portland      8.9     19.9       0.4          2.4
# 76111  2012-03-07  Portland      9.4     20.8       0.4          2.6
# 76112  2012-03-08  Portland     12.1     22.2       0.0          8.0
#
#        Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 76103      10.4          SE           41.0        SSE  ...        65.0
# ...

# %%
df.describe()
# Out:
#             MinTemp       MaxTemp      Rainfall   Evaporation      Sunshine  \
# count  75001.000000  75175.000000  73884.000000  37280.000000  30464.000000
# mean      11.271084     22.257790      2.360311      5.212366      7.327101
# std        6.226131      6.935675      8.293909      4.149631      3.842799
# min       -8.500000     -4.800000      0.000000      0.000000      0.000000
# 25%        6.800000     17.500000      0.000000      2.400000      4.400000
# 50%       11.400000     21.800000      0.000000      4.400000      8.100000
# 75%       16.100000     26.600000      0.600000      7.000000     10.400000
# max       31.900000     47.300000    371.000000    145.000000     14.500000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm   Humidity9am   Humidity3pm  \
# count   69991.000000  74732.000000  74118.000000  74292.000000  73864.000000
# mean       40.245032     13.952858     18.564532     71.145978     52.196022
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76113 entries, 0 to 76112
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           76113 non-null  object
#  1   Location       76113 non-null  object
#  2   MinTemp        75001 non-null  float64
#  3   MaxTemp        75175 non-null  float64
#  4   Rainfall       73884 non-null  float64
#  5   Evaporation    37280 non-null  float64
#  6   Sunshine       30464 non-null  float64
#  7   WindGustDir    69983 non-null  object
#  8   WindGustSpeed  69991 non-null  float64
#  9   WindDir9am     69197 non-null  object
#  10  WindDir3pm     73308 non-null  object
#  11  WindSpeed9am   74732 non-null  float64
#  12  WindSpeed3pm   74118 non-null  float64
#  13  Humidity9am    74292 non-null  float64
#  14  Humidity3pm    73864 non-null  float64
#  15  Pressure9am    65523 non-null  float64
#  16  Pressure3pm    65576 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1112
# MaxTemp            938
# Rainfall          2229
# Evaporation      38833
# Sunshine         45649
# WindGustDir       6130
# WindGustSpeed     6122
# WindDir9am        6916
# WindDir3pm        2805
# WindSpeed9am      1381
# WindSpeed3pm      1995
# Humidity9am       1821
# Humidity3pm       2249
# Pressure9am      10590
# Pressure3pm      10537
# Cloud9am         30077
# Cloud3pm         31035
# Temp9am           1481
# Temp3pm           1963
# RainToday         2230
# RainTomorrow      2229
# dtype: int64

# %%
df1 = df.drop(['Sunshine','Evaporation','Cloud9am','Cloud3pm'],axis =1)

# %%
from sklearn.preprocessing import LabelEncoder
lbl = LabelEncoder()
for i in df1.columns:
  df[i] = lbl.fit_transform(df[i])

# %%
from sklearn.preprocessing import LabelEncoder
lbl = LabelEncoder()
for i in df1.columns:
  df1[i] = lbl.fit_transform(df1[i])

# %%
from sklearn.impute import SimpleImputer
si  = SimpleImputer(missing_values = np.nan,strategy  = "mean")
df1.iloc[:,:] = si.fit_transform(df1.iloc[:,:])

# %%
plt.plot(df1['MaxTemp'])

# %%
plt.scatter(df['Evaporation'],df['RainToday'])

# %%
X = df1.drop(['Date','RainTomorrow'],axis =1)
Y = df1['RainTomorrow']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,random_state=0,test_size=.2)

# %%
'''from sklearn.preprocessing import StandardScaler
strd = StandardScaler()
x_train = strd.fit_transform(x_train)'''
# Out:
# 'from sklearn.preprocessing import StandardScaler\nstrd = StandardScaler()\nx_train = strd.fit_transform(x_train)'

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=160,max_depth =10,criterion= 'log_loss',n_jobs= -1,max_features= 20)
clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=10, max_features=20,
#                        n_estimators=160, n_jobs=-1)

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.8341325625697957
